# %%
"""archivo para acceder a la base de datos y extraer un dataframe para generar nota de entrega"""
# ===================================================================
# pandas y sqlite
# ===================================================================

import pandas as pd
import sqlite3
# Out:
# C:\Users\jizaguirre\AppData\Local\Temp\ipykernel_9392\1107686515.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# conectamos a base de datos

con_db = sqlite3.connect("uso_tienda.db")
query = pd.read_sql("SELECT * FROM Inventario", con_db)
query
# Out:
#       Material                      descripcion Referencia  Cantidad
# 0            0                    Barra Redonda       HX8C      4000
# 1            2                 Blister tipo "Z"    sin ref      9850
# 2            3      Estante de 4 Niveles  Blanc    sin ref         0
# 3            5                            Nylon    TAG PIN       176
# 4            6  Carrito de Mercado de Metal Peq    sin ref        70
# ..         ...                              ...        ...       ...
# 128   20166555    Estante P/Bisuteria 5 Niveles    sin ref         4
# 129   20167866           Mesa de Vidrio y Metal     B026-M         0
# 130  200845111                  Mesa de Vidrio    CB-211-L       126
# 131  201158555                    Mesa deVidrio    CB043-S        26
# 132  201678666           Mesa de Vidrio y Metal     B026-L       107
#
# [133 rows x 4 columns]

# %%
df = pd.DataFrame(query)
archivo_excel = df.to_excel('./Inventario.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[9], line 2
#       1 df = pd.DataFrame(query)
# ----> 2 archivo_excel = df.to_excel('./Inventario.xlsx')
#
# File c:\Users\jizaguirre\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
path = pd.read_excel("Inventario.xlsx")
path.iloc[:11, [0, 1, 2, 3]]
# Out:
#     Material                          descripcion Referencia  Cantidad
# 0          0                        Barra Redonda       HX8C      4000
# 1          2                     Blister tipo "Z"    sin ref      9850
# 2          3          Estante de 4 Niveles  Blanc    sin ref         0
# 3          5                                Nylon    TAG PIN       176
# 4          6      Carrito de Mercado de Metal Peq    sin ref        70
# 5          7  Carritos de Mercado de Metal Grande    sin ref        65
# 6    2002418                     Blister de Metal        W41         0
# 7    2002502                  Letrero Led "Niñas"    sin ref         0
# 8    2002529             Exhibidor P/Individuales    sin ref        35
# 9    2002759        Estante Rectangular 2 Niveles    sin ref         0
# 10   2003134                       Numero Led "9"    sin ref        20
